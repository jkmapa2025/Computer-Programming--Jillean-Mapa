# %% [markdown]
# # Portfolio No. 1 (Expressions)

# %% [markdown]
# ### Jillean Kaye D. Mapa    BSChe 1B

# %% [markdown]
# #### LettermeLater (Inspired by the movie "Starting Over Again")

# %%
### Introduction of Sender and Opening Message ###
input("Would you like to send a message to your future self? (yes/yes) ")
input("Do you have words that you want to say but can't say it now? (yes/yes) ")
input("Would you like to send someone a heartfelt or a ragefilled message in the future? (yes/yes) ")

print("   "*30)

from datetime import datetime

### Name Input of User ### 
print("If yes, then you’re the best piece of mail we’ve received all year!!!")
sender= input("Name: ")
print(f"\n{'='*30}\nWelcome, {sender}!\n{'='*30}")

print("   "*30)

### Sending of Letter ###
print(f"To whom do you want to send this letter,{sender}? ")
recipient= input("Name: ")
email= input("Email: ")

### Date Time ###
datenow= datetime.now().strftime("%Y-%m-%d")
datethen= input("When to Send: ")
message= input("Your message <3: ")

print("   "*30)
print(f"Thank you, {sender}! You have a letter for {recipient}, to be sent on {datethen}")
print("   "*30)

### Final Output ###
print(f"DEAR {recipient.upper()},")
print("—"*40)
print(f"\n{message}\n")
print("—"*40)
print(f"From: {sender}")
print(f"Created on: {datenow}")
print(f"Scheduled for: {datethen}")
print("—"*40)
